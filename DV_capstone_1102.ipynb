# %% [markdown]
# <a href="https://colab.research.google.com/github/Gltknzk/DA_Assignments/blob/master/DV_capstone_1102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
store = pd.read_csv("store_sharing.csv")

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
store.head()
# Out:
#              timestamp  cnt   t1  ...  is_holiday  is_weekend  season
# 0  2015-01-04 00:00:00  182  3.0  ...         0.0         1.0     3.0
# 1  2015-01-04 01:00:00  138  3.0  ...         0.0         1.0     3.0
# 2  2015-01-04 02:00:00  134  2.5  ...         0.0         1.0     3.0
# 3  2015-01-04 03:00:00   72  2.0  ...         0.0         1.0     3.0
# 4  2015-01-04 04:00:00   47  2.0  ...         0.0         1.0     3.0
#
# [5 rows x 10 columns]

# %%
store.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
ax= sns.countplot(store.season)
plt.xticks(rotation=0);

# %%
# season

# %%
ax= sns.countplot(store.is_holiday)
plt.xticks(rotation=0);

# %%
# is_holiday

# %%
ax= sns.countplot(store.is_weekend)
plt.xticks(rotation=0);

# %%
# is_weekend

# %%
ax= sns.countplot(store.weather_code)
plt.xticks(rotation=0);

# %%
# weather_code

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
store.dtypes
# Out:
# timestamp        object
# cnt               int64
# t1              float64
# t2              float64
# hum             float64
# wind_speed      float64
# weather_code    float64
# is_holiday      float64
# is_weekend      float64
# season          float64
# dtype: object

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
store["timestamp"]=pd.to_datetime(store.timestamp)

# %%
store["year_month"]= store.timestamp.dt.strftime("%Y-%m").astype(str)

# %%
store.year_month
# Out:
# 0        2015-01
# 1        2015-01
# 2        2015-01
# 3        2015-01
# 4        2015-01
#           ...
# 17409    2017-01
# 17410    2017-01
# 17411    2017-01
# 17412    2017-01
# 17413    2017-01
# Name: year_month, Length: 17414, dtype: object

# %%
store["year"]=store.timestamp.dt.strftime("%Y").astype(int)
store.year
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 17409    2017
# 17410    2017
# 17411    2017
# 17412    2017
# 17413    2017
# Name: year, Length: 17414, dtype: int64

# %%
store["month"]=store.timestamp.dt.strftime("%m").astype(int)
store.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 17409    1
# 17410    1
# 17411    1
# 17412    1
# 17413    1
# Name: month, Length: 17414, dtype: int64

# %%
store["day_of_month"]=store.timestamp.dt.strftime("%d").astype(int)
store.day_of_month
# Out:
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 17409    3
# 17410    3
# 17411    3
# 17412    3
# 17413    3
# Name: day_of_month, Length: 17414, dtype: int64

# %%
store["day_of_week"]=store.timestamp.dt.weekday.astype(int)
store.day_of_week
# Out:
# 0        6
# 1        6
# 2        6
# 3        6
# 4        6
#         ..
# 17409    1
# 17410    1
# 17411    1
# 17412    1
# 17413    1
# Name: day_of_week, Length: 17414, dtype: int64

# %%
store["hour"]=store.timestamp.dt.strftime("%-H").astype(int)
store.hour
# Out:
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#          ..
# 17409    19
# 17410    20
# 17411    21
# 17412    22
# 17413    23
# Name: hour, Length: 17414, dtype: int64

# %%
store.head()
# Out:
#             timestamp  cnt   t1   t2  ...  year  month  day_of_month  day_of_week
# 0 2015-01-04 00:00:00  182  3.0  2.0  ...  2015      1             4            6
# 1 2015-01-04 01:00:00  138  3.0  2.5  ...  2015      1             4            6
# 2 2015-01-04 02:00:00  134  2.5  2.5  ...  2015      1             4            6
# 3 2015-01-04 03:00:00   72  2.0  2.0  ...  2015      1             4            6
# 4 2015-01-04 04:00:00   47  2.0  0.0  ...  2015      1             4            6
#
# [5 rows x 15 columns]

# %%
store.set_index("timestamp", inplace=True)

# %%
df.head()
# Out:
#                      cnt   t1   t2  ...  day_of_month  day_of_week  hour
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...             4            6     0
# 2015-01-04 01:00:00  138  3.0  2.5  ...             4            6     1
# 2015-01-04 02:00:00  134  2.5  2.5  ...             4            6     2
# 2015-01-04 03:00:00   72  2.0  2.0  ...             4            6     3
# 2015-01-04 04:00:00   47  2.0  0.0  ...             4            6     4
#
# [5 rows x 15 columns]

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
store.head()
# Out:
#                      cnt   t1   t2  ...  day_of_month  day_of_week  hour
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...             4            6     0
# 2015-01-04 01:00:00  138  3.0  2.5  ...             4            6     1
# 2015-01-04 02:00:00  134  2.5  2.5  ...             4            6     2
# 2015-01-04 03:00:00   72  2.0  2.0  ...             4            6     3
# 2015-01-04 04:00:00   47  2.0  0.0  ...             4            6     4
#
# [5 rows x 15 columns]

# %%
#fig, plt(figuresize=(12,6))
sns.heatmap(store.corr(), data=store)

# %%
# for all variables

# %%
plt.figure(figsize=(2,6))
sns.heatmap(store.corr().loc[:,["cnt"]],annot=True)

# %%
# for the target variable

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
df_corr = store.corr()
df_corr[['cnt']].plot(kind='barh')
plt.figure(figsize=(16,6))

# %%
#with pandas

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
plt.figure(figsize=(16,6))
sns.lineplot(x=store.index, y="cnt", data=store)

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
plt.figure(figsize=(16,6))
sns.lineplot(x="year_month", y="cnt", data=store, ci=None)

# %%
# with lineplot

# %%
sns.lineplot(data=store, x="year_month", y="cnt", ci=95)

# %%
# with lineplot

# %%
plt.figure(figsize=(16,6))
sns.pointplot(x="month", y="cnt", data=store, ci=95)

# %%
# with pointplot

# %%
plt.figure(figsize=(16,6))
sns.barplot(x="month", y="cnt", data=store, ci=95)

# %%
# with barplot

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
plt.figure(figsize=(16,6))
sns.lineplot(x="hour", y="cnt", data=store, ci=95, hue="is_holiday")

# %%
# with lineplot (*whether it is a holiday or not*)

# %%
plt.figure(figsize=(16,6))
sns.lineplot(x="hour", y="cnt", data=store, ci=95, hue="season")

# %%
# with lineplot (*You may want to see seasonal breakdowns*)

# %%
plt.figure(figsize=(16,6))
sns.pointplot(x="hour", y="cnt", data=store, ci=95)

# %%
plt.figure(figsize=(16,6))
sns.pointplot(x="hour", y="cnt", data=store, ci=95, hue="is_holiday")

# %%
plt.figure(figsize=(16,4))
sns.pointplot(x="hour", y="cnt", data=store, ci=95, hue="is_weekend")

# %%
plt.figure(figsize=(16,6))
sns.pointplot(x="hour", y="cnt", data=store, ci=95, hue="season")

# %%
# with pointplot

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
store.day_of_week.value_counts()
# Out:
# 0    2508
# 6    2505
# 1    2505
# 3    2492
# 2    2489
# 5    2465
# 4    2450
# Name: day_of_week, dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.barplot(x="day_of_week", y="cnt", data=store, ci=95,hue="is_weekend")

# %%
plt.figure(figsize=(16,6))
sns.pointplot(x="hour", y="cnt", data=store, ci=95, hue="is_holiday")

# %%
# with barplot

# %%
plt.figure(figsize=(16,6))
sns.pointplot(x="day_of_week", y="cnt", data=store, ci=95, hue="season")

# %%
# with pointplot

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
plt.figure(figsize=(16,6))
sns.lineplot(x="day_of_month", y="cnt", data=store, ci=95)

# %%
#with lineplot
# Out:
# day_of_month    1     2     3     4     5   ...    27    28    29    30   31
# cnt           1077  1088  1128  1144  1141  ...  1131  1063  1080  1156  968
#
# [1 rows x 31 columns]

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
plt.figure(figsize=(9,6))
sns.barplot(x="year", y="cnt", data=store)

# %%
# with barplot

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="season", y="cnt", data=store)

# %%
# with barplot

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
a= store.is_weekend.value_counts()
a
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
plt.figure(figsize=(16,6))
label=["weekday","weekend"]
plt.pie(a, labels=label, autopct='%.1f%%')
plt.show()

# %%
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
# pie chart

# %%
fig, ax=plt.subplots(figsize=(10,6))
ax=sns.countplot(x='is_weekend', data=store)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
for p in ax.patches:
    ax.annotate(round(p.get_height()), (p.get_x()+0.35, p.get_height()+10));

# %%
# with countplot

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
fig, ax=plt.subplots(figsize=(10,6))
ax=sns.countplot(x='weather_code', data=store)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %%
# with countplot

# %%
sns.catplot(x='weather_code', col="season", data=store, kind="count")

# %%
# with catplot

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
